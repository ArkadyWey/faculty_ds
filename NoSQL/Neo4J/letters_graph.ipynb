# %% [markdown]
# ## Overview
# In this exercise we will:
#     - load some data
#     - inspect it
#     - do some cleaning
#     - model our data
#     - load it into the graph
#     - gain some insights
#
# This exercise is left largely open and the commented cells are only intended as a guideline. Please try to implement some solution yourself before looking at the solution.

# %%
import pandas as pd
import neomodel

# %%
# Configure Neo4J

from neomodel import config

user = "neo4j"
password = "password"

config.DATABASE_URL = f'bolt://{user}:{password}@localhost:7687'
    
def drop_delete_everything():
    '''Helpful to wipe the db properly'''
    db.cypher_query("MATCH (n) DETACH DELETE n")
    
    neomodel.core.remove_all_labels()

# %% [markdown]
# # Now that we have things setup lets look at our data
#
# It's a simple collection records of letters sent between several people. You can assume that there is only one person with each name. i.e. it is the same Will in all entries marked Will

# %%
data = pd.read_csv("./letters.csv", names=["Sender", "Reciever", "date"])
data
# Out:
#                 Sender          Reciever               date
# 0                 John              Will          25.5.1801
# 1                Scott              Will          13.3.1805
# 2                Sarah             Kevin         24.11.1807
# 3              Michael              Will         24.10.1803
# 4              Michael              Will           5.2.1805
# 5              Michael  Wordsworth, John          17.2.1805
# 6                 Lisa             Kevin               1805
# 7                 Lisa             Kevin               1805
# 8              Michael              Will           3.3.1805
# 9              Michael              Will          24.3.1805
# 10             Michael              Will          21.7.1805
# 11             Michael              Will          11.8.1805
# 12             Michael              Will         25.11.1805
# 13             Michael              Will           5.3.1806
# 14             Michael              Will          29.6.1806
# ...

# %% [markdown]
# ## Is it clean? (hint: it's not)
# ## How can I account for the missing values/ wrong types

# %%
# Do some cleaning here

# %% [markdown]
# # Construct the data model

# %%
# Data model

# %%
# Load the data into the graph

# %% [markdown]
# How many nodes are in the graph? - Answer: 44

# %% [markdown]
# How many connections are in the graph? - Answer: 207

# %% [markdown]
# Which node is most connected? - Answer: Rory
